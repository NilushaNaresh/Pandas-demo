# %%
import pandas as pd

# %%
df= pd.read_csv("Data/survey_results_public.csv",index_col='Respondent')
schema_df= pd.read_csv("Data/survey_results_schema.csv",index_col='Column')

# %%
schema_df.head()
# Out:
#                                                  QuestionText
# Column
# Respondent  Randomized respondent ID number (not in order ...
# MainBranch  Which of the following options best describes ...
# Hobbyist                              Do you code as a hobby?
# Age         What is your age (in years)? If you prefer not...
# Age1stCode  At what age did you write your first line of c...

# %%
pd.set_option('display.max_columns',85)
pd.set_option('display.max_rows',85)

# %%
df.head()
# Out:
#                                                    MainBranch Hobbyist   Age  \
# Respondent
# 1                              I am a developer by profession      Yes   NaN
# 2                              I am a developer by profession       No   NaN
# 3                                 I code primarily as a hobby      Yes   NaN
# 4                              I am a developer by profession      Yes  25.0
# 5           I used to be a developer by profession, but no...      Yes  31.0
#
#            Age1stCode CompFreq  CompTotal  ConvertedComp             Country  \
# Respondent
# 1                  13  Monthly        NaN            NaN             Germany
# 2                  19      NaN        NaN            NaN      United Kingdom
# 3                  15      NaN        NaN            NaN  Russian Federation
# 4                  18      NaN        NaN            NaN             Albania
# 5                  16      NaN        NaN            NaN       United States
#
# ...

# %%
df.shape
# Out:
# (64461, 60)

# %%
df.shape
# Out:
# (64461, 60)

# %%
pd.get_option("display.max_columns")
# Out:
# 85

# %%
pd.get_option("display.max_rows")
# Out:
# 85

# %%
pd.set_option("display.max_columns",10)

# %%
df.iloc[0]
# Out:
# MainBranch                                         I am a developer by profession
# Hobbyist                                                                      Yes
# Age                                                                           NaN
# Age1stCode                                                                     13
# CompFreq                                                                  Monthly
# CompTotal                                                                     NaN
# ConvertedComp                                                                 NaN
# Country                                                                   Germany
# CurrencyDesc                                                        European Euro
# CurrencySymbol                                                                EUR
# DatabaseDesireNextYear                                       Microsoft SQL Server
# ...

# %%
df.columns
# Out:
# Index(['MainBranch', 'Hobbyist', 'Age', 'Age1stCode', 'CompFreq', 'CompTotal',
#        'ConvertedComp', 'Country', 'CurrencyDesc', 'CurrencySymbol',
#        'DatabaseDesireNextYear', 'DatabaseWorkedWith', 'DevType', 'EdLevel',
#        'Employment', 'Ethnicity', 'Gender', 'JobFactors', 'JobSat', 'JobSeek',
#        'LanguageDesireNextYear', 'LanguageWorkedWith',
#        'MiscTechDesireNextYear', 'MiscTechWorkedWith',
#        'NEWCollabToolsDesireNextYear', 'NEWCollabToolsWorkedWith', 'NEWDevOps',
#        'NEWDevOpsImpt', 'NEWEdImpt', 'NEWJobHunt', 'NEWJobHuntResearch',
#        'NEWLearn', 'NEWOffTopic', 'NEWOnboardGood', 'NEWOtherComms',
#        'NEWOvertime', 'NEWPurchaseResearch', 'NEWPurpleLink', 'NEWSOSites',
#        'NEWStuck', 'OpSys', 'OrgSize', 'PlatformDesireNextYear',
#        'PlatformWorkedWith', 'PurchaseWhat', 'Sexuality', 'SOAccount',
#        'SOComm', 'SOPartFreq', 'SOVisitFreq', 'SurveyEase', 'SurveyLength',
# ...

# %%
df.columns[0:3]
# Out:
# Index(['MainBranch', 'Hobbyist', 'Age'], dtype='object')

# %%
people = {
    'name': ['Naresh', 'Nilusha', 'Arjuna'],
     'last name': ['Ramanathan', 'Gnanachandran', 'Naresh'],
     'email': ['nari@gmail.com','nilu@gmail.com','arjun@gmail.com']
}

# %%
schema_df.sort_index()
# Out:
#                                                                    QuestionText
# Column
# Age                           What is your age (in years)? If you prefer not...
# Age1stCode                    At what age did you write your first line of c...
# CompFreq                       Is that compensation weekly, monthly, or yearly?
# CompTotal                     What is your current total compensation (salar...
# ConvertedComp                 Salary converted to annual USD salaries using ...
# Country                                                      Where do you live?
# CurrencyDesc                  Which currency do you use day-to-day? If your ...
# CurrencySymbol                Which currency do you use day-to-day? If your ...
# DatabaseDesireNextYear        Which database environments have you done exte...
# DatabaseWorkedWith            Which database environments have you done exte...
# DevType                       Which of the following describe you? Please se...
# ...

# %%
schema_df.loc['YearsCode','QuestionText']
# Out:
# 'Including any education, how many years have you been coding in total?'

# %%
df.loc[1,'YearsCode']
# Out:
# '36'

# %%
df.loc[3,'Country']
# Out:
# 'Russian Federation'

# %%
schema_df.loc['Country','QuestionText']
# Out:
# 'Where do you live?'

# %%
filt = df['LanguageWorkedWith'].str.contains('Python',na=False)
df.loc[filt,'LanguageWorkedWith']
# Out:
# Respondent
# 3                                 Objective-C;Python;Swift
# 8                                               Python;SQL
# 10                     HTML/CSS;Java;JavaScript;Python;SQL
# 13                                     C;JavaScript;Python
# 15        Bash/Shell/PowerShell;C;HTML/CSS;Java;Python;SQL
#                                ...
# 61561    Bash/Shell/PowerShell;HTML/CSS;JavaScript;Perl...
# 62391       C++;HTML/CSS;JavaScript;Python;Ruby;TypeScript
# 63077              C++;HTML/CSS;Java;JavaScript;Python;SQL
# 63640    Bash/Shell/PowerShell;C;C#;C++;HTML/CSS;Java;J...
# 64867    Assembly;Bash/Shell/PowerShell;C;C#;C++;Dart;G...
# Name: LanguageWorkedWith, Length: 25287, dtype: object

# %%
filt.count()
# Out:
# 64461

# %%
filt
# Out:
# Respondent
# 1        False
# 2        False
# 3         True
# 4        False
# 5        False
#          ...
# 64858    False
# 64867     True
# 64898    False
# 64925    False
# 65112    False
# Name: LanguageWorkedWith, Length: 64461, dtype: bool

# %%
df['Hobbyist']
# Out:
# Respondent
# 1        Yes
# 2         No
# 3        Yes
# 4        Yes
# 5        Yes
#         ...
# 64858    Yes
# 64867    Yes
# 64898    Yes
# 64925    Yes
# 65112    Yes
# Name: Hobbyist, Length: 64461, dtype: object

# %%
df['Hobbyist'].replace({'Yes':True,'No':False})
# Out:
# Respondent
# 1         True
# 2        False
# 3         True
# 4         True
# 5         True
#          ...
# 64858     True
# 64867     True
# 64898     True
# 64925     True
# 65112     True
# Name: Hobbyist, Length: 64461, dtype: object

# %%
df['Hobbyist'] = df['Hobbyist'].map({'Yes':True,'No':False})

# %%
df.rename(columns={'Gender':'Sex'})
# Out:
#                                                    MainBranch Hobbyist   Age  \
# Respondent
# 1                              I am a developer by profession     True   NaN
# 2                              I am a developer by profession    False   NaN
# 3                                 I code primarily as a hobby     True   NaN
# 4                              I am a developer by profession     True  25.0
# 5           I used to be a developer by profession, but no...     True  31.0
# ...                                                       ...      ...   ...
# 64858                                                     NaN     True   NaN
# 64867                                                     NaN     True   NaN
# 64898                                                     NaN     True   NaN
# 64925                                                     NaN     True   NaN
# 65112                                                     NaN     True   NaN
#
# ...

# %%
df.sort_values(by=['Country','ConvertedComp'],ascending=[True,False],inplace=True)

# %%
df[['Country','ConvertedComp']].head(500)
# Out:
#                 Country  ConvertedComp
# Respondent
# 62788       Afghanistan      1000000.0
# 65381       Afghanistan      1000000.0
# 65456       Afghanistan      1000000.0
# 38672       Afghanistan       231192.0
# 28374       Afghanistan       130000.0
# ...                 ...            ...
# 888           Argentina            NaN
# 1448          Argentina            NaN
# 3212          Argentina            NaN
# 4076          Argentina            NaN
# 4409          Argentina            NaN
#
# [500 rows x 2 columns]

# %%
df['ConvertedComp'].nlargest(5)
# Out:
# Respondent
# 5725     2000000.0
# 54263    2000000.0
# 43430    2000000.0
# 59279    2000000.0
# 46711    2000000.0
# Name: ConvertedComp, dtype: float64

# %%
df['ConvertedComp'].median()
# Out:
# 54049.0

# %%
df['Hobbyist'].value_counts()
# Out:
# True     50388
# False    14028
# Name: Hobbyist, dtype: int64

# %%
df['JobSeek']
# Out:
# Respondent
# 62788                 I am actively looking for a job
# 65381                                             NaN
# 65456                                             NaN
# 38672                                             NaN
# 28374    I am not interested in new job opportunities
#                              ...
# 60055                                             NaN
# 61121                                             NaN
# 61570                                             NaN
# 61918                                             NaN
# 62605                                             NaN
# Name: JobSeek, Length: 64461, dtype: object

# %%
schema_df.loc['JobSeek','QuestionText']
# Out:
# 'Which of the following best describes your current job-seeking status?'

# %%
country_grp = df.groupby(['Country'])
country_grp

# %%
country_grp.get_group('India')
# Out:
#                                                    MainBranch Hobbyist   Age  \
# Respondent
# 37655                          I am a developer by profession    False   NaN
# 36976       I am not primarily a developer, but I write co...    False   NaN
# 3332                           I am a developer by profession     True   NaN
# 8457                           I am a developer by profession     True  22.0
# 21351                          I am a developer by profession    False  98.0
# ...                                                       ...      ...   ...
# 54757                                                     NaN     True   NaN
# 55407                                                     NaN     True   NaN
# 62464                                                     NaN     True   NaN
# 62954                                                     NaN     True   NaN
# 64236                                                     NaN     True   NaN
#
# ...

# %%
df['Sexuality'].value_counts()
# Out:
# Straight / Heterosexual                                  40118
# Bisexual                                                  1918
# Gay or Lesbian                                             978
# Bisexual;Straight / Heterosexual                           258
# Queer                                                      249
# Bisexual;Queer                                             191
# Gay or Lesbian;Queer                                        90
# Straight / Heterosexual;Queer                               56
# Bisexual;Gay or Lesbian                                     40
# Bisexual;Gay or Lesbian;Straight / Heterosexual;Queer       39
# Bisexual;Gay or Lesbian;Queer                               24
# Gay or Lesbian;Straight / Heterosexual                      13
# Bisexual;Straight / Heterosexual;Queer                      10
# Bisexual;Gay or Lesbian;Straight / Heterosexual              8
# Name: Sexuality, dtype: int64

# %%
country_grp.get_group('India')['Sexuality'].value_counts()
# Out:
# Straight / Heterosexual                                  3609
# Bisexual                                                  155
# Bisexual;Straight / Heterosexual                           12
# Gay or Lesbian                                             10
# Queer                                                       9
# Bisexual;Gay or Lesbian;Straight / Heterosexual;Queer       3
# Gay or Lesbian;Straight / Heterosexual                      3
# Bisexual;Queer                                              3
# Bisexual;Straight / Heterosexual;Queer                      1
# Gay or Lesbian;Queer                                        1
# Bisexual;Gay or Lesbian;Straight / Heterosexual             1
# Straight / Heterosexual;Queer                               1
# Name: Sexuality, dtype: int64

# %%
country_grp

# %%
df['ConvertedComp']
# Out:
# Respondent
# 62788    1000000.0
# 65381    1000000.0
# 65456    1000000.0
# 38672     231192.0
# 28374     130000.0
#            ...
# 60055          NaN
# 61121          NaN
# 61570          NaN
# 61918          NaN
# 62605          NaN
# Name: ConvertedComp, Length: 64461, dtype: float64

# %%
country_grp['ConvertedComp'].agg(['mean','median']).loc['Canada']
# Out:
# mean      115101.775465
# median     68068.000000
# Name: Canada, dtype: float64

# %%
fil=df['Country']=='China'

# %%
df[fil]
# Out:
#                                                    MainBranch Hobbyist   Age  \
# Respondent
# 37094                          I am a developer by profession    False   NaN
# 22426                          I am a developer by profession     True  35.0
# 20098                          I am a developer by profession     True  35.0
# 50261                          I am a developer by profession    False   NaN
# 8434                           I am a developer by profession     True  28.0
# ...                                                       ...      ...   ...
# 65339                          I am a developer by profession     True   NaN
# 65435       I am not primarily a developer, but I write co...     True   NaN
# 65506                          I am a developer by profession    False   NaN
# 65510                          I am a developer by profession    False   NaN
# 65519       I am not primarily a developer, but I write co...     True   NaN
#
# ...

# %%
df.loc[fil]['LanguageWorkedWith'].str.contains('Python').sum()
# Out:
# 158

# %%
country_grp['LanguageWorkedWith'].apply(lambda x: x.str.contains('Python').sum())
# Out:
# Country
# Afghanistan                              11
# Albania                                  13
# Algeria                                  40
# Andorra                                   3
# Angola                                    1
#                                        ...
# Venezuela, Bolivarian Republic of...     29
# Viet Nam                                102
# Yemen                                     1
# Zambia                                    4
# Zimbabwe                                 13
# Name: LanguageWorkedWith, Length: 183, dtype: int64

# %%
df['Country']
# Out:
# Respondent
# 62788    Afghanistan
# 65381    Afghanistan
# 65456    Afghanistan
# 38672    Afghanistan
# 28374    Afghanistan
#             ...
# 60055            NaN
# 61121            NaN
# 61570            NaN
# 61918            NaN
# 62605            NaN
# Name: Country, Length: 64461, dtype: object

# %%
country_responders = df['Country'].value_counts()

# %%
country_responders
# Out:
# United States     12469
# India              8403
# United Kingdom     3896
# Germany            3890
# Canada             2191
#                   ...
# Nauru                 1
# Chad                  1
# Mali                  1
# Lesotho               1
# Kiribati              1
# Name: Country, Length: 183, dtype: int64

# %%
know_python=country_grp['LanguageWorkedWith'].apply(lambda x: x.str.contains('Python').sum())

# %%
know_python
# Out:
# Country
# Afghanistan                              11
# Albania                                  13
# Algeria                                  40
# Andorra                                   3
# Angola                                    1
#                                        ...
# Venezuela, Bolivarian Republic of...     29
# Viet Nam                                102
# Yemen                                     1
# Zambia                                    4
# Zimbabwe                                 13
# Name: LanguageWorkedWith, Length: 183, dtype: int64

# %%
df[['Country','LanguageWorkedWith']]
# Out:
#                 Country                LanguageWorkedWith
# Respondent
# 62788       Afghanistan                               NaN
# 65381       Afghanistan                               NaN
# 65456       Afghanistan                               NaN
# 38672       Afghanistan                               NaN
# 28374       Afghanistan  Bash/Shell/PowerShell;C;C++;Java
# ...                 ...                               ...
# 60055               NaN                               NaN
# 61121               NaN                               NaN
# 61570               NaN                               NaN
# 61918               NaN                               NaN
# 62605               NaN                               NaN
#
# [64461 rows x 2 columns]

# %%
python_user = pd.concat([know_python,country_responders],axis='columns')

# %%
python_user
# Out:
#                                       LanguageWorkedWith  Country
# Afghanistan                                           11       84
# Albania                                               13       54
# Algeria                                               40       94
# Andorra                                                3       13
# Angola                                                 1        9
# ...                                                  ...      ...
# Venezuela, Bolivarian Republic of...                  29       70
# Viet Nam                                             102      364
# Yemen                                                  1        7
# Zambia                                                 4       21
# Zimbabwe                                              13       31
#
# [183 rows x 2 columns]

# %%
python_user.loc['India']
# Out:
# LanguageWorkedWith    2670
# Country               8403
# Name: India, dtype: int64

# %%
df['Country'].dropna()
# Out:
# Respondent
# 62788    Afghanistan
# 65381    Afghanistan
# 65456    Afghanistan
# 38672    Afghanistan
# 28374    Afghanistan
#             ...
# 55739       Zimbabwe
# 56060       Zimbabwe
# 61917       Zimbabwe
# 64129       Zimbabwe
# 64506       Zimbabwe
# Name: Country, Length: 64072, dtype: object

# %%
df.isna()
# Out:
#             MainBranch  Hobbyist   Age  Age1stCode  CompFreq  ...  \
# Respondent                                                    ...
# 62788            False     False  True        True     False  ...
# 65381            False     False  True       False     False  ...
# 65456            False     False  True       False     False  ...
# 38672            False     False  True       False     False  ...
# 28374            False     False  True       False     False  ...
# ...                ...       ...   ...         ...       ...  ...
# 60055             True     False  True        True      True  ...
# 61121             True     False  True        True      True  ...
# 61570             True     False  True        True      True  ...
# 61918             True     False  True        True      True  ...
# 62605             True     False  True        True      True  ...
#
#             WebframeWorkedWith  WelcomeChange  WorkWeekHrs  YearsCode  \
# Respondent
# ...

# %%
df['YearsCode'].head(10)
# Out:
# Respondent
# 62788                   NaN
# 65381                    30
# 65456    More than 50 years
# 38672                    40
# 28374                    17
# 9839                     10
# 63848                    14
# 51862                     5
# 51509                     8
# 44484                     8
# Name: YearsCode, dtype: object

# %%
df.dtypes
# Out:
# MainBranch                       object
# Hobbyist                         object
# Age                             float64
# Age1stCode                       object
# CompFreq                         object
# CompTotal                       float64
# ConvertedComp                   float64
# Country                          object
# CurrencyDesc                     object
# CurrencySymbol                   object
# DatabaseDesireNextYear           object
# DatabaseWorkedWith               object
# DevType                          object
# EdLevel                          object
# Employment                       object
# Ethnicity                        object
# Gender                           object
# JobFactors                       object
# JobSat                           object
# JobSeek                          object
# LanguageDesireNextYear           object
# LanguageWorkedWith               object
# MiscTechDesireNextYear           object
# ...

# %%
df['YearsCode'].unique()
# Out:
# array([nan, '30', 'More than 50 years', '40', '17', '10', '14', '5', '8',
#        '9', '4', '6', '3', '2', '35', '1', 'Less than 1 year', '7', '12',
#        '50', '19', '20', '11', '15', '24', '27', '28', '16', '22', '13',
#        '18', '25', '38', '34', '23', '32', '21', '42', '33', '26', '29',
#        '39', '48', '36', '47', '41', '37', '31', '43', '44', '45', '46',
#        '49'], dtype=object)

# %%
df['YearsCode'].replace('More than 50 years',55,inplace=True)
df['YearsCode'].replace('Less than 1 year',0,inplace=True)

# %%
df['YearsCode'].dtypes
# Out:
# dtype('O')

# %%
df['YearsCode']=df['YearsCode'].astype(float)

# %%
df['YearsCode'].dtypes
# Out:
# dtype('float64')

# %%
df['YearsCode'].mean()
# Out:
# 12.718968864849872

# %%
df
# Out:
#                                 MainBranch Hobbyist  Age  \
# Respondent
# 62788       I am a developer by profession     True  NaN
# 65381       I am a developer by profession    False  NaN
# 65456       I am a developer by profession     True  NaN
# 38672       I am a developer by profession    False  NaN
# 28374       I am a developer by profession     True  NaN
# ...                                    ...      ...  ...
# 60055                                  NaN    False  NaN
# 61121                                  NaN     True  NaN
# 61570                                  NaN    False  NaN
# 61918                                  NaN     True  NaN
# 62605                                  NaN    False  NaN
#
#                       Age1stCode CompFreq  ...  WebframeWorkedWith  \
# Respondent                                 ...
# 62788                        NaN   Weekly  ...                 NaN
# 65381                          8   Weekly  ...                 NaN
# ...

# %%
filt = (df['Country'] == 'India')
india_df = df[filt]
india_df.head()
# Out:
#                                                    MainBranch Hobbyist   Age  \
# Respondent
# 37655                          I am a developer by profession    False   NaN
# 36976       I am not primarily a developer, but I write co...    False   NaN
# 3332                           I am a developer by profession     True   NaN
# 8457                           I am a developer by profession     True  22.0
# 21351                          I am a developer by profession    False  98.0
#
#            Age1stCode CompFreq  ...  WebframeWorkedWith  \
# Respondent                      ...
# 37655              15  Monthly  ...     ASP.NET;Express
# 36976              20   Yearly  ...                 NaN
# 3332               19  Monthly  ...        Flask;Spring
# 8457               18  Monthly  ...                 NaN
# 21351              17   Weekly  ...              jQuery
#
#                                        WelcomeChange WorkWeekHrs YearsCode  \
# Respondent
# ...

# %%
india_df.to_csv('Data/modified.csv')
